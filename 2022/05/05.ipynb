# %% [markdown]
# # Немного о сетевых протоколах.

# %% [markdown]
# Построение сети, которая могла бы соединить два произвольных компьютера во всем мире - задача не из простых. Такая сеть должна быть надежной и работать, даже если некоторые узлы выйдут из
# строя; сеть должна иметь возможность расти, например, подключать новые страны. Она должна
# обеспечить качество обслуживания: скачать без проблем большие файлы или передавать данные
# без задержек. В этой сети необходимо обеспечить безопасность передачи данных.

# %% [markdown]
# ![](images/multilevel_network.jpg)

# %% [markdown]
# На практике такая задача решается при помощи декомпозиции сети на несколько уровней взаимодействия, каждый из которых решает определенную задачу. Уровни взаимодействия изолированы друг от друга - если что-то меняется на одном уровне, то на других все остается неизменным

# %% [markdown]
# **Интерфейc** – набор примитивных операций, которые нижний уровень предоставляет верхнему.
#
# **Протокол** – это правила и соглашения, используемые для связи уровня N одного компьютера
# с уровнем N другого компьютера.

# %% [markdown]
# ![](images/message_incapsulation.jpg)

# %% [markdown]
# Самая популярная модель сетевых взаимодействий - **модель TCP/IP** - состоит из четырех уровней
#
# 1. **Уровень сетевых интерфейсов (Network access layer)** рассматривает любую подсеть, входящую в составную сеть, как средство транспортировки пакетов между двумя соседними узлами. Задачи этого уровня:
#     * упаковка IP-пакета в единицу передаваемых данных промежуточной сети
#     * преобразования IP-адресов в адреса технологии данной промежуточной сети.
#
# 2. **Сетевой уровень (network layer)** служит для образования единой транспортной системы, которая объединяет несколько сетей.
#
# 3. **Транспортный уровень (Transport layer)** обеспечивает передачу данных между процессами с той степенью надежности, которая им требуется. Примером протоколов транспортного уровня являяюся TCP и UDP
#
# 4. **Прикладной уровень (Application layer)** представляет собой набор разнообразных протоколов, с помощью которых пользователи сети получают доступ к разделяемым ресурсам. В модели считается, что если приложению нужны какие-то функции представления информации, например, шифрование, то оно должно само их реализовывать.

# %% [markdown]
# # Протокол HTTP

# %% [markdown]
# **HTTP** – это протокол прикладного уровня для передачи гипертекста.
#
# Все взаимодействие HTTP происходит между клиентом и сервером. Клиент – это конечный
# потребитель услуг сервера, а сервер – это поставщик услуг хранения обработки информации.
# Клиенту необходимо получить какие-то данные, он делает запрос к серверу, сервер подготавли-
# вает эти данные и отдает клиенту

# %% [markdown]
# #### Структура запроса

# %% [markdown]
# ![](images/request_structure.jpg)

# %% [markdown]
# Методы протокола:
# * **GET**: используется для получения какой-то информации;
# * **HEAD**: аналогично GET-запросу, но без тела запроса;
# * **POST**: отсылает от клиента данные на сервер;
# * **PATCH/DELETE**: запрос на изменение/удаление отправленных данных

# %% [markdown]
# Поля заголовка, следующие за строкой состояния, позволяют уточнять запрос, т.е. передавать
# серверу дополнительную информацию. Возможные поля
# * **Host** — доменное имя или IP-адрес узла, к которому обращается клиент;
# * **Referer** — URL, откуда перешел клиент;
# * **Accept** — MIME-типы данных, обрабатываемых клиентом;
# * **Accept-Charset** — перечень поддерживаемых кодировок;
# * **Content-Type** — MIME-тип данных, содержащихся в теле запроса;
# * **Content-Length** — число символов, содержащихся в теле запроса;
# * **Connection** — используется для управления TCP-соединением;
# * **User-Agent** — информация о клиенте.

# %% [markdown]
# #### Структура ответа

# %% [markdown]
# ![](images/respose_structure.jpg)

# %% [markdown]
# В совокупности строка состояния и заголовки называются заголовком ответа. Строка состояния состоит из версии протокола и статуса HTTP-ответа и расшифровки этого ответа. Существует 5 классов ответов:
# * **1xx** — специальный класс сообщений, называемых информационными. Означает, что сервер продолжает обработку запроса. (101 Switching Protocols);
# * **2xx** — успешная обработка запроса клиента. (200 Ok, 201 Created);
# * **3xx** — перенаправление запроса. (301 Moved Permanently, 302 Found);
# * **4xx** — ошибка клиента. (400 Bad Request, 403 Forbidden, 404 Not Found);
# * **5xx** — ошибка сервера. (500 Internal Server Error, 502 Bad Gateway)

# %% [markdown]
# Возможные поля заголовка ответа:
# * **Server** — имя и номер версии сервера;
# * **Allow** — список методов, допустимых для данного ресурса;
# * **Content-Type** — MIME-тип данных, содержащихся в теле ответа сервера;
# * **Content-Length** — число символов, содержащихся в теле ответа сервера;
# * **Last-Modifed** — дата и время последнего изменения ресурса;
# * **Expires** — дата и время, когда информация станет устаревшей;
# * **Location** — расположение ресурса;
# * **Cache-Control** — директива управления кэшированием

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in /home/andrey/PG/python-3rd-term-seminars/python-3rd-term/env/lib/python3.6/site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/andrey/PG/python-3rd-term-seminars/python-3rd-term/env/lib/python3.6/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/andrey/PG/python-3rd-term-seminars/python-3rd-term/env/lib/python3.6/site-packages (from requests) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/andrey/PG/python-3rd-term-seminars/python-3rd-term/env/lib/python3.6/site-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/andrey/PG/python-3rd-term-seminars/python-3rd-term/env/lib/python3.6/site-packages (from requests) (2.0.12)

# %% [markdown]
# # Библиотека requests

# %%
# сделаем простой get-запрос

import requests
# Make a Request
r = requests.get('http://httpbin.org/get')

# %%
print(r.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-633c44b5-158a2bcc7095384d6fe55828"
#   },
#   "origin": "93.175.29.93",
#   "url": "http://httpbin.org/get"
# }

# %%
# теперь сделаем запрос post

r = requests.post('http://httpbin.org/post')
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-633c44a1-586a346470f0d29071c65620"
#   },
#   "json": null,
#   "origin": "93.175.29.93",
#   "url": "http://httpbin.org/post"
# }

# %%
# Параметры запроса 

payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('http://httpbin.org/get', params=payload)
print(r.text)
# Out:
# {
#   "args": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-633c4575-7620fef458a86b281fe28f2d"
#   },
#   "origin": "93.175.29.93",
#   "url": "http://httpbin.org/get?key1=value1&key2=value2"
# }

# %%
# Чтобы передать данные в Post/Put/Patch запросах, 
# нужно передать в соответствующие методы поля data.

r = requests.put('http://httpbin.org/put', data = {'key':'value'})
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-633c45a7-6d9aa97f1092b0a03a8e6a8b"
#   },
#   "json": null,
#   "origin": "93.175.29.93",
#   "url": "http://httpbin.org/put"
# }

# %%
# Зачастую параметры запроса передаются json-файлами.
# json можно либо построить руками, либо 
# использовать встроенный в библиотеку механизм

import json
url = 'http://httpbin.org/post'
r1 = requests.post(url, data=json.dumps({'key':'value'}))
r2 = requests.post(url, json={'key':'value'})

# %%
print(r1.text)
# Out:
# {
#   "args": {},
#   "data": "{\"key\": \"value\"}",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "16",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-633c462c-64bf78f613164f10798c962d"
#   },
#   "json": {
#     "key": "value"
#   },
#   "origin": "93.175.29.93",
#   "url": "http://httpbin.org/post"
# }

# %%
print(r2.text)
# Out:
# {
#   "args": {},
#   "data": "{\"key\": \"value\"}",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "16",
#     "Content-Type": "application/json",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-633c462c-3586a19b70ce05651479b6f5"
#   },
#   "json": {
#     "key": "value"
#   },
#   "origin": "93.175.29.93",
#   "url": "http://httpbin.org/post"
# }

# %%
# передача файла осуществляется следующим образом

with open('test.txt', 'wb') as f:
    f.write((1).to_bytes(1, byteorder='big'))

# POST a Multipart-Encoded File
url = 'http://httpbin.org/post'
files = {
    'file': ('test.txt', open('test.txt','rb'))
}
r = requests.post(url, files=files)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {
#     "file": "\u0001"
#   },
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "145",
#     "Content-Type": "multipart/form-data; boundary=60f8b647d993a7fa73551e632fb688ed",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-633c46eb-0bf988907e02bce34c0ac434"
#   },
#   "json": null,
#   "origin": "93.175.29.93",
#   "url": "http://httpbin.org/post"
# }

# %%
# Передачу заголовков можно осуществить аналогично

url = 'http://httpbin.org/get'
headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get(url, headers=headers)
print(r.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "my-app/0.0.1",
#     "X-Amzn-Trace-Id": "Root=1-633c4715-260ac49b1b5107455852d3f5"
#   },
#   "origin": "93.175.29.93",
#   "url": "http://httpbin.org/get"
# }

# %%
# содержание ответа

r = requests.get('http://httpbin.org/get')
print(type(r.text), r.text)
# Out:
# <class 'str'> {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-633c1b6b-0cbafa72418c733927426e10"
#   },
#   "origin": "93.175.9.74",
#   "url": "http://httpbin.org/get"
# }

# %%
print(type(r.content), r.content)
# Out:
# <class 'bytes'> b'{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.27.1", \n    "X-Amzn-Trace-Id": "Root=1-633c1b6b-0cbafa72418c733927426e10"\n  }, \n  "origin": "93.175.9.74", \n  "url": "http://httpbin.org/get"\n}\n'

# %%
print(type(r.json()), r.json())
# Out:
# <class 'dict'> {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.27.1', 'X-Amzn-Trace-Id': 'Root=1-633c1b6b-0cbafa72418c733927426e10'}, 'origin': '93.175.9.74', 'url': 'http://httpbin.org/get'}

# %%
# Статус ответа 

print(r.status_code)
print(r.status_code == requests.codes.ok)
# Out:
# 200
# True

# %%
bad_r = requests.get('http://httpbin.org/status/404')
print(bad_r.status_code)
bad_r.raise_for_status()
# Out:
# 404
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-52-c5a29ad7cd75> in <module>
#       1 bad_r = requests.get('http://httpbin.org/status/404')
#       2 print(bad_r.status_code)
# ----> 3 bad_r.raise_for_status()
#
# ~/PG/python-3rd-term-seminars/python-3rd-term/env/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     958
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#     962     def close(self):
#
# HTTPError: 404 Client Error: NOT FOUND for url: http://httpbin.org/status/404

# %% [markdown]
# # Работа с Web API
#
# Web API - это набор тех или иных url-ов сайта, позволяющих получать информацию с него путем HTTP запросов. Сегодня мы поработаем с API мессенджера ВК

# %%
app_id = "51441305"

# %%
access_token = "vk1.a.GCwvqjr45aeihXdGkY6tW-O69p8k6j_yKMgtq7Ez0-WFyN92l5Ufgxu2FoeThz2obwH5bwBl9UddM5j-Pc756XlGy3KBP3zjz-24nTusfKdZOmMtvIZn43NEAd7br3UPx6RK7E-ZApx4ArywMhWlfMgQEPpfa93JlmL-bEiJrWXm-t2WNiaY_kAuCKpQs-IB"

# %%
header =  "https://api.vk.com/method/"
method_name = 'friends.getSuggestions'

# %%
get_friends = requests.get(
    header + method_name,
    params={
        "access_token": access_token,
        "v": "5.131",
    }
)

# %%
get_friends.json()['response']
# Out:
# {'count': 100,
#  'items': [{'id': 64790650,
#    'first_name': 'Иван',
#    'last_name': 'Утешев',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 182177483,
#    'first_name': 'Ринат',
#    'last_name': 'Камалов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 288135092,
#    'first_name': 'Александр',
#    'last_name': 'Шестаков',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 172372431,
#    'first_name': 'Егор',
#    'last_name': 'Байтенов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 147854333,
#    'first_name': 'Алла',
#    'last_name': 'Зайцева',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 174459462,
#    'first_name': 'Ванесса',
#    'last_name': 'Нарцева',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 64129135,
#    'first_name': 'Анатолий',
#    'last_name': 'Морозов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 753086292,
#    'first_name': 'Ubei',
#    'last_name': 'Fang',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 751758320,
#    'first_name': 'Галина',
#    'last_name': 'Саввотина',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 269104659,
#    'first_name': 'Татьяна',
#    'last_name': 'Зотова',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 977893,
#    'first_name': 'Катерина',
#    'last_name': 'Беклемышева',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 581086149,
#    'first_name': 'Клай',
#    'last_name': 'Монтег',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 157414705,
#    'first_name': 'Ярослав',
#    'last_name': 'Ивченков',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 207625929,
#    'first_name': 'Александр',
#    'last_name': 'Кирильченко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 62076725,
#    'first_name': 'Владислав',
#    'last_name': 'Поляков',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 575974633,
#    'first_name': 'Николай',
#    'last_name': 'Науменко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 190742854,
#    'first_name': 'Владимир',
#    'last_name': 'Белонин',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 5473142,
#    'first_name': 'Тимофей',
#    'last_name': 'Люско',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 19160711,
#    'first_name': 'Антон',
#    'last_name': 'Скубачевский',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 406253434,
#    'first_name': 'Nikita',
#    'last_name': 'Shagin',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 76025405,
#    'first_name': 'Юля',
#    'last_name': 'Парфёнова',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 179437977,
#    'first_name': 'Тимофей',
#    'last_name': 'Горшков',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 173680733,
#    'first_name': 'Роман',
#    'last_name': 'Москаленко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 46483621,
#    'first_name': 'Василий',
#    'last_name': 'Дзюбенко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 170301062,
#    'first_name': 'Yegor',
#    'last_name': 'Kravets',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 345550778,
#    'first_name': 'Катя',
#    'last_name': 'Самсонова',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 145437342,
#    'first_name': 'Данил',
#    'last_name': 'Скуридин',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 433700432,
#    'first_name': 'Karina',
#    'last_name': 'Andrianova',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 117172019,
#    'first_name': 'Алина',
#    'last_name': 'Кондакова',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 286553427,
#    'first_name': 'Дмитрий',
#    'last_name': 'Гуляев',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 245995450,
#    'first_name': 'Лео',
#    'last_name': 'Винокуров',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 136211635,
#    'first_name': 'Полина',
#    'last_name': 'Селина',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 46229240,
#    'first_name': 'Лёня',
#    'last_name': 'Князев',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 2153814,
#    'first_name': 'Евгений',
#    'last_name': 'Молчанов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 120615819,
#    'first_name': 'Александр',
#    'last_name': 'Бойко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 252931928,
#    'first_name': 'Маша',
#    'last_name': 'Демьяненко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 88620086,
#    'first_name': 'Илья',
#    'last_name': 'Захаров',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 45056539,
#    'first_name': 'Вова',
#    'last_name': 'Ревар',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 252371149,
#    'first_name': 'Andrey',
#    'last_name': 'Vovk',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 138319448,
#    'first_name': 'Галина',
#    'last_name': 'Саввотина',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 223851324,
#    'first_name': 'Владик',
#    'last_name': 'Негависпыч',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 138444691,
#    'first_name': 'Егор',
#    'last_name': 'Бедринский',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 172223080,
#    'first_name': 'Тимофей',
#    'last_name': 'Лапин',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 53839732,
#    'first_name': 'Данил',
#    'last_name': 'Чулков',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 177439490,
#    'first_name': 'Лена',
#    'last_name': 'Мельникова',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 443412541,
#    'first_name': 'Владислав',
#    'last_name': 'Бем',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 332080104,
#    'first_name': 'Никита',
#    'last_name': 'Коданев',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 99866676,
#    'first_name': 'Елизавета',
#    'last_name': 'Кремень',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 204388322,
#    'first_name': 'Кирилл',
#    'last_name': 'Пучков',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 320303548,
#    'first_name': 'Коля',
#    'last_name': 'Петрачков',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 14914624,
#    'first_name': 'Павел',
#    'last_name': 'Останин',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 425680330,
#    'first_name': 'Виталий',
#    'last_name': 'Ерошин',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 232917209,
#    'first_name': 'Роман',
#    'last_name': 'Емельянов',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 118945825,
#    'first_name': 'Данил',
#    'last_name': 'Шайхелисламов',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 154268404,
#    'first_name': 'Фёдор',
#    'last_name': 'Чупраков',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 23467255,
#    'first_name': 'Талгат',
#    'last_name': 'Сапаров',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 102785076,
#    'first_name': 'Антонина',
#    'last_name': 'Тихонова',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 223376150,
#    'first_name': 'Kirill',
#    'last_name': 'Acharya',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 32732208,
#    'first_name': 'Кирилл',
#    'last_name': 'Ветошев',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 283740484,
#    'first_name': 'Мария',
#    'last_name': 'Телешева',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 50342671,
#    'first_name': 'Виталий',
#    'last_name': 'Угнивенко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 223454361,
#    'first_name': 'Арина',
#    'last_name': 'Чумаченко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 439968975,
#    'first_name': 'Анна',
#    'last_name': 'Зизганова',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 214282493,
#    'first_name': 'Ира',
#    'last_name': 'Жулябина',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 10335432,
#    'first_name': 'Nikita',
#    'last_name': 'Stavtsev',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 48389408,
#    'first_name': 'Максим',
#    'last_name': 'Пыталев',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 294082709,
#    'first_name': 'Саня',
#    'last_name': 'Богданов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 36836630,
#    'first_name': 'Роман',
#    'last_name': 'Шарапов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 152615668,
#    'first_name': 'Александр',
#    'last_name': 'Ващилко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 212703422,
#    'first_name': 'Павел',
#    'last_name': 'Бурнышев',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 136568134,
#    'first_name': 'Михаил',
#    'last_name': 'Точилин',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 69817449,
#    'first_name': 'Артём',
#    'last_name': 'Агафонов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 279810624,
#    'first_name': 'Iluxa',
#    'last_name': 'Oso',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 254080446,
#    'first_name': 'Батыржан',
#    'last_name': 'Юсуп-Ахунов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 119450298,
#    'first_name': 'Алёна',
#    'last_name': 'Сидорова',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 175680439,
#    'first_name': 'Аня',
#    'last_name': 'Дмитриенко',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 78949766,
#    'first_name': 'Денис',
#    'last_name': 'Нарцев',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 247630779,
#    'first_name': 'Никита',
#    'last_name': 'Плетнев',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 162620791,
#    'first_name': 'Ростислав',
#    'last_name': 'Аникин',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 285527194,
#    'first_name': 'Яна',
#    'last_name': 'Зенкова',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 39226477,
#    'first_name': 'Ярослав',
#    'last_name': 'Маштаков',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 2384937,
#    'first_name': 'Сергей',
#    'last_name': 'Жестков',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 101333487,
#    'first_name': 'Алексей',
#    'last_name': 'Григорьев',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 247257321,
#    'first_name': 'Михаил',
#    'last_name': 'Гончаров',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 156692231,
#    'first_name': 'Владислав',
#    'last_name': 'Топоровский',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 167306708,
#    'first_name': 'Толя',
#    'last_name': 'Угазин',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 156626668,
#    'first_name': 'Нина',
#    'last_name': 'Скубачевская',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 73179917,
#    'first_name': 'Иван',
#    'last_name': 'Петров',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 40971639,
#    'first_name': 'Даня',
#    'last_name': 'Амосов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 146290046,
#    'first_name': 'Айдар',
#    'last_name': 'Файрушин',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 243025003,
#    'first_name': 'Максим',
#    'last_name': 'Иванов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 61163882,
#    'first_name': 'Анна',
#    'last_name': 'Ласкина',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 614521828,
#    'first_name': 'Екатерина',
#    'last_name': 'Бородич',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 152509251,
#    'first_name': 'Саша',
#    'last_name': 'Колесов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 731500274,
#    'first_name': 'Лера',
#    'last_name': 'Зайцева',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 39681728,
#    'first_name': 'Дмитрий',
#    'last_name': 'Плещеев',
#    'can_access_closed': False,
#    'is_closed': True},
#   {'id': 30651610,
#    'first_name': 'Александр',
#    'last_name': 'Кильянов',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 680412283,
#    'first_name': 'Sameed',
#    'last_name': 'Ahmed',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 329534891,
#    'first_name': 'Sena',
#    'last_name': 'Kolkin',
#    'can_access_closed': True,
#    'is_closed': False},
#   {'id': 69052569,
#    'first_name': 'Ангелина',
#    'last_name': 'Торшина',
#    'can_access_closed': True,
#    'is_closed': False}]}

# %%
get_music = requests.get(
    "https://api.vk.com/method/groups.search",
    params={
        "q": "Music",
        "access_token": access_token,
        "v": "5.131",
    }
)

# %%
get_music.json()
# Out:
# {'response': {'count': 145246,
#   'items': [{'id': 23995866,
#     'name': 'E:\\music\\',
#     'screen_name': 'e_music',
#     'is_closed': 0,
#     'type': 'page',
#     'photo_50': 'https://sun1-99.userapi.com/s/v1/if1/jlOgGpIrSx3xLU_M8vJ-5KsPHKkSCioQlmQgeNt_9qcpJ9rhlqfgqkDA1k5HRqt4k6R0s4Ey.jpg?size=50x50&quality=96&crop=90,90,720,720&ava=1',
#     'photo_100': 'https://sun1-99.userapi.com/s/v1/if1/vdwJxwvOdIdS70Q4Yu6_uaBZNmxY4IZ750JhNyyvcTWWb_quJmHKlBRsyiSu6XXnvSNwgYBG.jpg?size=100x100&quality=96&crop=90,90,720,720&ava=1',
